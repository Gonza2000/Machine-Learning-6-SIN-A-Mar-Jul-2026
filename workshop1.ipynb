# %%
#Imports pandas and assign it to the variable 'pd'
import  pandas as pd
#We often import Numpy (numerical python) with pandas 
#we will import that and assing it to the variable 'np'
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Get the csv into a variable for manipulation

unemployment= pd.read_csv('./data/country_total.csv')

# %%
#See data type
type(unemployment)
# Out:
# pandas.DataFrame

# %%
#Get the first 5 rows
unemployment.head()
# Out:
#   country seasonality    month  unemployment  unemployment_rate
# 0      at         nsa  1993.01        171000                4.5
# 1      at         nsa  1993.02        175000                4.6
# 2      at         nsa  1993.03        166000                4.4
# 3      at         nsa  1993.04        157000                4.1
# 4      at         nsa  1993.05        147000                3.9

# %%
#Get data type for each column
unemployment.dtypes
# Out:
# country                  str
# seasonality              str
# month                float64
# unemployment           int64
# unemployment_rate    float64
# dtype: object

# %%
#Get number of rows and columns
unemployment.shape
# Out:
# (20796, 5)

# %%
#Get all columns 
unemployment.columns
# Out:
# Index(['country', 'seasonality', 'month', 'unemployment', 'unemployment_rate'], dtype='str')

# %%
#Get a general resume about the DataFrame
unemployment.describe()
# Out:
#               month  unemployment  unemployment_rate
# count  20796.000000  2.079600e+04       19851.000000
# mean    1999.401290  7.900818e+05           8.179764
# std        7.483751  1.015280e+06           3.922533
# min     1983.010000  2.000000e+03           1.100000
# 25%     1994.090000  1.400000e+05           5.200000
# 50%     2001.010000  3.100000e+05           7.600000
# 75%     2006.010000  1.262250e+06          10.000000
# max     2010.120000  4.773000e+06          20.900000

# %%
my_list=['a','b','c','d','e','f']
lista = my_list[len(my_list)-4:]
print(lista)
# Out:
# ['c', 'd', 'e', 'f']

# %%
my_list[2:]
# Out:
# ['c', 'd', 'e', 'f']

# %%
countries= pd.read_csv('./data/countries.csv')

# %%
countries.head()
# Out:
#   country google_country_code country_group   name_en   name_fr     name_de  \
# 0      at                  AT            eu   Austria  Autriche  Österreich
# 1      be                  BE            eu   Belgium  Belgique     Belgien
# 2      bg                  BG            eu  Bulgaria  Bulgarie   Bulgarien
# 3      hr                  HR        non-eu   Croatia   Croatie    Kroatien
# 4      cy                  CY            eu    Cyprus    Chypre      Zypern
#
#     latitude  longitude
# 0  47.696554  13.345980
# 1  50.501045   4.476674
# 2  42.725674  25.482322
# 3  44.746643  15.340844
# 4  35.129141  33.428682

# %%
countries.describe()
# Out:
#         latitude  longitude
# count  30.000000  30.000000
# mean   49.092609  14.324579
# std     7.956624  11.257010
# min    35.129141  -8.239122
# 25%    43.230916   6.979186
# 50%    49.238087  14.941462
# 75%    54.090400  23.351690
# max    64.950159  35.439795

# %%
countries.shape
# Out:
# (30, 8)

# %%
#Get third row with the column google_country_code

countries.loc[3,'google_country_code']
# Out:
# 'HR'

# %%
#Get the first 4 rows and all the columns 

countries.loc[:4,:]
# Out:
#   country google_country_code country_group   name_en   name_fr     name_de  \
# 0      at                  AT            eu   Austria  Autriche  Österreich
# 1      be                  BE            eu   Belgium  Belgique     Belgien
# 2      bg                  BG            eu  Bulgaria  Bulgarie   Bulgarien
# 3      hr                  HR        non-eu   Croatia   Croatie    Kroatien
# 4      cy                  CY            eu    Cyprus    Chypre      Zypern
#
#     latitude  longitude
# 0  47.696554  13.345980
# 1  50.501045   4.476674
# 2  42.725674  25.482322
# 3  44.746643  15.340844
# 4  35.129141  33.428682

# %%
#Get all the rows, and columns form the first to the forth, using indexes becaus iloc uses indexes
countries.iloc[:,:4]
# Out:
#    country google_country_code country_group  \
# 0       at                  AT            eu
# 1       be                  BE            eu
# 2       bg                  BG            eu
# 3       hr                  HR        non-eu
# 4       cy                  CY            eu
# 5       cz                  CZ            eu
# 6       dk                  DK            eu
# 7       ee                  EE            eu
# 8       fi                  FI            eu
# 9       fr                  FR            eu
# 10      de                  DE            eu
# 11      gr                  GR            eu
# 12      hu                  HU            eu
# 13      ie                  IE            eu
# 14      it                  IT            eu
# 15      lv                  LV            eu
# 16      lt                  LT            eu
# 17      lu                  LU            eu
# 18      mt                  MT            eu
# 19      nl                  NL            eu
# ...
